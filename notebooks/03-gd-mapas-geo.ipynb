# %%
import folium
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from folium import plugins
from shapely.geometry import Point

from src.config import DADOS_LIMPOS, DADOS_GEO_ORIGINAIS, DADOS_GEO_MEDIAN
from src.graficos import PALETTE, SCATTER_ALPHA

sns.set_theme(palette="bright", style='dark')

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room  population_per_room
# 0           0.146591             0.365909
# 1           0.155797             0.338217
# 2           0.260274             0.472016
# 3           0.252679             0.622321
# 4           0.203216             0.442162

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17515 non-null  float64
#  1   latitude                  17515 non-null  float64
#  2   housing_median_age        17515 non-null  int8
#  3   total_rooms               17515 non-null  int16
#  4   total_bedrooms            17515 non-null  int16
#  5   population                17515 non-null  int16
#  6   households                17515 non-null  int16
#  7   median_income             17515 non-null  float64
#  8   median_house_value        17515 non-null  int32
#  9   ocean_proximity           17515 non-null  category
#  10  median_income_cat         17515 non-null  int64
#  11  rooms_per_household       17515 non-null  float64
#  12  population_per_household  17515 non-null  float64
#  13  bedrooms_per_room         17515 non-null  float64
#  14  population_per_room       17515 non-null  float64
# dtypes: category(1), float64(7), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17515.000000  17515.000000        17515.000000  17515.000000
# mean    -119.513273     35.606241           27.266115   2514.896489
# std        1.985391      2.148380           11.324505   1593.711025
# min     -124.300000     32.540000            1.000000      6.000000
# 25%     -121.605000     33.920000           18.000000   1468.000000
# 50%     -118.470000     34.250000           28.000000   2136.000000
# 75%     -117.980000     37.680000           36.000000   3128.000000
# max     -114.550000     41.950000           51.000000  11026.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17515.000000  17515.000000  17515.000000   17515.000000
# mean       515.906537   1385.809877    484.407194       3.700456
# std        320.946868    844.291144    295.661729       1.541810
# min          2.000000      3.000000      2.000000       0.499900
# 25%        300.000000    816.000000    287.000000       2.552300
# 50%        438.000000   1195.000000    415.000000       3.483800
# 75%        643.000000   1737.000000    605.000000       4.625000
# max       2205.000000   5804.000000   1979.000000      10.594100
#
#        median_house_value  median_income_cat  rooms_per_household  \
# count        17515.000000       17515.000000         17515.000000
# mean        189688.061547           2.954953             5.260755
# std          96037.570708           1.006643             1.128166
# min          14999.000000           1.000000             1.714286
# 25%         114300.000000           2.000000             4.455787
# 50%         171700.000000           3.000000             5.210526
# 75%         243900.000000           4.000000             5.963796
# max         500000.000000           5.000000            10.352941
#
#        population_per_household  bedrooms_per_room  population_per_room
# count              17515.000000       17515.000000         17515.000000
# mean                   2.929839           0.211285             0.584600
# std                    0.685911           0.047841             0.206795
# min                    0.750000           0.113535             0.166667
# 25%                    2.469410           0.176860             0.447914
# 50%                    2.850365           0.203350             0.523885
# 75%                    3.301620           0.238610             0.659836
# max                    5.392384           0.406295             1.529833

# %%
gdf_counties = gpd.read_file(DADOS_GEO_ORIGINAIS)

gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...

# %%
#criando a informação de geometria usando a longitute e latitude para utilizar no geopandas

geometry = gpd.points_from_xy(df['longitude'], df['latitude'])
gdf = gpd.GeoDataFrame(df, geometry=geometry)

# %%
gdf.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room  population_per_room               geometry
# 0           0.146591             0.365909  POINT (-122.23 37.88)
# 1           0.155797             0.338217  POINT (-122.22 37.86)
# 2           0.260274             0.472016  POINT (-122.26 37.84)
# 3           0.252679             0.622321  POINT (-122.26 37.85)
# 4           0.203216             0.442162  POINT (-122.26 37.84)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17515 non-null  float64
#  1   latitude                  17515 non-null  float64
#  2   housing_median_age        17515 non-null  int8
#  3   total_rooms               17515 non-null  int16
#  4   total_bedrooms            17515 non-null  int16
#  5   population                17515 non-null  int16
#  6   households                17515 non-null  int16
#  7   median_income             17515 non-null  float64
#  8   median_house_value        17515 non-null  int32
#  9   ocean_proximity           17515 non-null  category
#  10  median_income_cat         17515 non-null  int64
#  11  rooms_per_household       17515 non-null  float64
#  12  population_per_household  17515 non-null  float64
#  13  bedrooms_per_room         17515 non-null  float64
#  14  population_per_room       17515 non-null  float64
#  15  geometry                  17515 non-null  geometry
# dtypes: category(1), float64(7), geometry(1), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.4 MB

# %%
gdf.crs = "EPSG:4326"

# %%
gdf_counties = gdf_counties.set_crs(epsg=4326)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_counties.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...

# %%
#Unindo os dataframes para obter a informação de Condado de cada bloco de domicilio no nosso Dataframe
gdf_joined = gpd.sjoin(gdf, gdf_counties, how='left', predicate = 'within')

gdf_joined.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    ...  population_per_household  bedrooms_per_room  population_per_room  \
# 0  ...                  2.555556           0.146591             0.365909
# 1  ...                  2.109842           0.155797             0.338217
# 2  ...                  2.026891           0.260274             0.472016
# 3  ...                  2.640152           0.252679             0.622321
# 4  ...                  2.362768           0.203216             0.442162
#
#                 geometry  index_right     name        fullname abbrev abcode  \
# 0  POINT (-122.23 37.88)         34.0  Alameda  Alameda County    ALA   c001
# 1  POINT (-122.22 37.86)         34.0  Alameda  Alameda County    ALA   c001
# 2  POINT (-122.26 37.84)         34.0  Alameda  Alameda County    ALA   c001
# 3  POINT (-122.26 37.85)         34.0  Alameda  Alameda County    ALA   c001
# 4  POINT (-122.26 37.84)         34.0  Alameda  Alameda County    ALA   c001
#
#   ansi
# 0  001
# 1  001
# 2  001
# 3  001
# 4  001
#
# [5 rows x 22 columns]

# %%
gdf_joined = gdf_joined.drop(
    columns = ['index_right','fullname','abcode','ansi']
)

gdf_joined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17515 non-null  float64
#  1   latitude                  17515 non-null  float64
#  2   housing_median_age        17515 non-null  int8
#  3   total_rooms               17515 non-null  int16
#  4   total_bedrooms            17515 non-null  int16
#  5   population                17515 non-null  int16
#  6   households                17515 non-null  int16
#  7   median_income             17515 non-null  float64
#  8   median_house_value        17515 non-null  int32
#  9   ocean_proximity           17515 non-null  category
#  10  median_income_cat         17515 non-null  int64
#  11  rooms_per_household       17515 non-null  float64
#  12  population_per_household  17515 non-null  float64
#  13  bedrooms_per_room         17515 non-null  float64
#  14  population_per_room       17515 non-null  float64
#  15  geometry                  17515 non-null  geometry
#  16  name                      17367 non-null  str
#  17  abbrev                    17367 non-null  str
# dtypes: category(1), float64(7), geometry(1), int16(4), int32(1), int64(1), int8(1), str(2)
# memory usage: 1.9 MB

# %%
#Condados não encontrados
gdf_joined[gdf_joined.isnull().any(axis=1)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1507     -124.30     41.80                  19         2672             552
# 1508     -124.23     41.75                  11         3159             616
# 1511     -124.22     41.73                  28         3003             699
# 1517     -124.30     41.84                  17         2677             531
# 1521     -119.94     38.96                  20         1451             386
# ...          ...       ...                 ...          ...             ...
# 17150    -119.30     34.27                  17         1527             503
# 17151    -119.29     34.26                  32         3295             764
# 17153    -119.29     34.23                  22         2486             608
# 17183    -119.23     34.15                  18         6213            1188
# 17209    -119.21     34.12                  15         5778            1285
#
#        population  households  median_income  median_house_value  \
# 1507         1298         478         1.9797               85800
# 1508         1343         479         2.4805               73200
# 1511         1530         653         1.7038               78300
# 1517         1244         456         3.0313              103600
# 1521          467         255         1.5536              212500
# ...           ...         ...            ...                 ...
# 17150         688         423         1.6007              187500
# 17151        1344         600         3.6007              395500
# 17153         709         523         2.9018              275000
# 17183        2679        1000         3.7480              380400
# 17209        1722         829         4.3427              305800
#
#       ocean_proximity  median_income_cat  rooms_per_household  \
# 1507       NEAR OCEAN                  2             5.589958
# 1508       NEAR OCEAN                  2             6.594990
# 1511       NEAR OCEAN                  2             4.598775
# 1517       NEAR OCEAN                  3             5.870614
# 1521           INLAND                  2             5.690196
# ...               ...                ...                  ...
# 17150      NEAR OCEAN                  2             3.609929
# 17151      NEAR OCEAN                  3             5.491667
# 17153      NEAR OCEAN                  2             4.753346
# 17183      NEAR OCEAN                  3             6.213000
# 17209      NEAR OCEAN                  3             6.969843
#
#        population_per_household  bedrooms_per_room  population_per_room  \
# 1507                   2.715481           0.206587             0.485778
# 1508                   2.803758           0.194998             0.425135
# 1511                   2.343032           0.232767             0.509491
# 1517                   2.728070           0.198356             0.464699
# 1521                   1.831373           0.266023             0.321847
# ...                         ...                ...                  ...
# 17150                  1.626478           0.329404             0.450557
# 17151                  2.240000           0.231866             0.407891
# 17153                  1.355641           0.244570             0.285197
# 17183                  2.679000           0.191212             0.431193
# 17209                  2.077201           0.222395             0.298027
#
#                     geometry name abbrev
# 1507     POINT (-124.3 41.8)  NaN    NaN
# 1508   POINT (-124.23 41.75)  NaN    NaN
# 1511   POINT (-124.22 41.73)  NaN    NaN
# 1517    POINT (-124.3 41.84)  NaN    NaN
# 1521   POINT (-119.94 38.96)  NaN    NaN
# ...                      ...  ...    ...
# 17150   POINT (-119.3 34.27)  NaN    NaN
# 17151  POINT (-119.29 34.26)  NaN    NaN
# 17153  POINT (-119.29 34.23)  NaN    NaN
# 17183  POINT (-119.23 34.15)  NaN    NaN
# 17209  POINT (-119.21 34.12)  NaN    NaN
#
# [148 rows x 18 columns]

# %%
linhas_faltantes = gdf_joined[gdf_joined.isnull().any(axis=1)].index
linhas_faltantes
# Out:
# Index([ 1507,  1508,  1511,  1517,  1521,  2154,  2193,  2201,  2203,  2219,
#        ...
#        15699, 15700, 15704, 15707, 15708, 17150, 17151, 17153, 17183, 17209],
#       dtype='int64', length=148)
