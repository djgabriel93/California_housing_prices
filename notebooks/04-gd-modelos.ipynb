# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room  population_per_room
# 0           0.146591             0.365909
# 1           0.155797             0.338217
# 2           0.260274             0.472016
# 3           0.252679             0.622321
# 4           0.203216             0.442162

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17515 non-null  float64
#  1   latitude                  17515 non-null  float64
#  2   housing_median_age        17515 non-null  int8
#  3   total_rooms               17515 non-null  int16
#  4   total_bedrooms            17515 non-null  int16
#  5   population                17515 non-null  int16
#  6   households                17515 non-null  int16
#  7   median_income             17515 non-null  float64
#  8   median_house_value        17515 non-null  int32
#  9   ocean_proximity           17515 non-null  category
#  10  median_income_cat         17515 non-null  int64
#  11  rooms_per_household       17515 non-null  float64
#  12  population_per_household  17515 non-null  float64
#  13  bedrooms_per_room         17515 non-null  float64
#  14  population_per_room       17515 non-null  float64
# dtypes: category(1), float64(7), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.3 MB

# %%
#Definir nossas colunas que serão preprocessadas
coluna_target = ['median_house_value']

coluna_one_hot_encoder = ['ocean_proximity']

coluna_ordinal_encoder = ['median_income_cat']

# %%
#Definir X e y
X = df.drop(columns = coluna_target)

y = df[coluna_target]

# %%
y
# Out:
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  226700
# 3                  140000
# 4                  158700
# ...                   ...
# 17510               78100
# 17511               77100
# 17512               92300
# 17513               84700
# 17514               89400
#
# [17515 rows x 1 columns]

# %%
#criar o preprocessamento

preprocessamento = ColumnTransformer(
    transformers = [
        ("one_hot_encoder", OneHotEncoder(drop='first'),coluna_one_hot_encoder),
        ("ordinal_encoder", OrdinalEncoder(categories='auto'),coluna_ordinal_encoder),
    ],
    remainder='passthrough',
)

# %%
#criar o target transformer

power_transformer = PowerTransformer()

# %%
# Definindo noss modelos de treino para comparação

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_Power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": power_transformer,
    },
}

# %%
#Treinar e validar modelos

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

resultados
# Out:
# {'DummyRegressor': {'fit_time': array([0.00671458, 0.00327921, 0.00374126, 0.0035913 , 0.00385618]),
#   'score_time': array([0.00573516, 0.00560236, 0.00478745, 0.00514913, 0.00483274]),
#   'test_r2': array([-8.79886502e-04, -7.01292589e-05, -3.90446967e-04, -1.07273469e-04,
#          -1.34175423e-04]),
#   'test_neg_mean_absolute_error': array([-76256.6430076 , -76449.68322658, -76241.74334592, -77052.4072976 ,
#          -77839.12138232]),
#   'test_neg_root_mean_squared_error': array([-95147.59926567, -96287.73388159, -95461.5544825 , -96172.37627931,
#          -97119.54792537])},
#  'LinearRegression': {'fit_time': array([0.02801228, 0.02647567, 0.02390361, 0.02386594, 0.02443337]),
#   'score_time': array([0.01271796, 0.01691222, 0.01267028, 0.01376247, 0.0122602 ]),
#   'test_r2': array([0.69028914, 0.66606835, 0.66104148, 0.6679513 , 0.66398948]),
#   'test_neg_mean_absolute_error': array([-39415.65518174, -40876.66288459, -41414.43293308, -40450.64599389,
#          -41326.95514596]),
#   'test_neg_root_mean_squared_error': array([-52927.94993511, -55639.66764696, -55567.0075938 , -55415.07805684,
#          -56292.94296357])},
#  'LinearRegression_Power': {'fit_time': array([0.06585741, 0.06475472, 0.06463027, 0.07514811, 0.05941772]),
#   'score_time': array([0.01311374, 0.01901579, 0.01825857, 0.01285505, 0.0131104 ]),
#   'test_r2': array([0.70007109, 0.66570053, 0.6583144 , 0.67260076, 0.66367802]),
#   'test_neg_mean_absolute_error': array([-37129.20908065, -39250.55109541, -39699.92931789, -38508.51980993,
#          -39632.27052963]),
#   'test_neg_root_mean_squared_error': array([-52085.40197984, -55670.30264662, -55790.09145761, -55025.73931183,
#          -56319.0271733 ])}}

# %%
#dataframe comparativo com os resultados de tempo e erros dos modelos para cada 'cross-validation'
df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                      model  fit_time score_time   test_r2  \
# 0           DummyRegressor  0.006715   0.005735  -0.00088
# 1           DummyRegressor  0.003279   0.005602  -0.00007
# 2           DummyRegressor  0.003741   0.004787  -0.00039
# 3           DummyRegressor  0.003591   0.005149 -0.000107
# 4           DummyRegressor  0.003856   0.004833 -0.000134
# 5         LinearRegression  0.028012   0.012718  0.690289
# 6         LinearRegression  0.026476   0.016912  0.666068
# 7         LinearRegression  0.023904    0.01267  0.661041
# 8         LinearRegression  0.023866   0.013762  0.667951
# 9         LinearRegression  0.024433    0.01226  0.663989
# 10  LinearRegression_Power  0.065857   0.013114  0.700071
# 11  LinearRegression_Power  0.064755   0.019016  0.665701
# 12  LinearRegression_Power   0.06463   0.018259  0.658314
# 13  LinearRegression_Power  0.075148   0.012855  0.672601
# 14  LinearRegression_Power  0.059418    0.01311  0.663678
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -76256.643008                    -95147.599266      0.01245
# 1                 -76449.683227                    -96287.733882     0.008882
# 2                 -76241.743346                    -95461.554483     0.008529
# 3                 -77052.407298                    -96172.376279      0.00874
# 4                 -77839.121382                    -97119.547925     0.008689
# 5                 -39415.655182                    -52927.949935      0.04073
# 6                 -40876.662885                    -55639.667647     0.043388
# 7                 -41414.432933                    -55567.007594     0.036574
# 8                 -40450.645994                    -55415.078057     0.037628
# 9                 -41326.955146                    -56292.942964     0.036694
# 10                -37129.209081                     -52085.40198     0.078971
# 11                -39250.551095                    -55670.302647     0.083771
# 12                -39699.929318                    -55790.091458     0.082889
# 13                 -38508.51981                    -55025.739312     0.088003
# 14                 -39632.27053                    -56319.027173     0.072528

# %%
#comparação das médias das métricas por modelo
df_resultados.groupby('model').mean()
# Out:
#                         fit_time score_time   test_r2  \
# model
# DummyRegressor          0.004237   0.005221 -0.000316
# LinearRegression        0.025338   0.013665  0.669868
# LinearRegression_Power  0.065962   0.015271  0.672073
#
#                        test_neg_mean_absolute_error  \
# model
# DummyRegressor                        -76767.919652
# LinearRegression                      -40696.870428
# LinearRegression_Power                -38844.095967
#
#                        test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                            -96037.762367     0.009458
# LinearRegression                          -55168.529239     0.039003
# LinearRegression_Power                    -54978.112514     0.081232

# %%
#gráfico comparativos das métricas de cada modelo
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# Podemos observar uma melhoria das métricas com o target transformer. A seguir vamos testar outro tipo de target transformer (Quantile Transformer)

# %%
quantile_transformer= QuantileTransformer(output_distribution='normal')

# %%
param_grid = {
    "transformer": [None, power_transformer, quantile_transformer]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    param_grid=param_grid,
    preprocessor=preprocessamento,
    target_transformer=power_transformer,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         transformers=[('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['ocean_proximity']),
#                                                                                       ('ordinal_encoder',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['median_income_cat'])])),
#                                                      ('reg',
#                                                       LinearRegression())]),
#                            transformer=QuantileTransformer(output_distribution='normal'))

# %%
grid_search.best_estimator_.transformer_
# Out:
# QuantileTransformer(output_distribution='normal')

# %%
# Definindo noss modelos de treino para comparação

regressors2 = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_Power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": power_transformer,
    },
     "LinearRegression_Quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}

# %%
#Treinar e validar modelos

resultados2 = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors2.items()
}

resultados2
# Out:
# {'DummyRegressor': {'fit_time': array([0.00595093, 0.00736761, 0.00528669, 0.00519919, 0.00514722]),
#   'score_time': array([0.00622034, 0.0101819 , 0.00726652, 0.00720882, 0.00927567]),
#   'test_r2': array([-8.79886502e-04, -7.01292589e-05, -3.90446967e-04, -1.07273469e-04,
#          -1.34175423e-04]),
#   'test_neg_mean_absolute_error': array([-76256.6430076 , -76449.68322658, -76241.74334592, -77052.4072976 ,
#          -77839.12138232]),
#   'test_neg_root_mean_squared_error': array([-95147.59926567, -96287.73388159, -95461.5544825 , -96172.37627931,
#          -97119.54792537])},
#  'LinearRegression': {'fit_time': array([0.03993893, 0.03187847, 0.03026104, 0.03026295, 0.0329802 ]),
#   'score_time': array([0.02079988, 0.01547098, 0.01552701, 0.01677394, 0.01505709]),
#   'test_r2': array([0.69028914, 0.66606835, 0.66104148, 0.6679513 , 0.66398948]),
#   'test_neg_mean_absolute_error': array([-39415.65518174, -40876.66288459, -41414.43293308, -40450.64599389,
#          -41326.95514596]),
#   'test_neg_root_mean_squared_error': array([-52927.94993511, -55639.66764696, -55567.0075938 , -55415.07805684,
#          -56292.94296357])},
#  'LinearRegression_Power': {'fit_time': array([0.06006742, 0.10533452, 0.10052919, 0.09156585, 0.06492591]),
#   'score_time': array([0.01622272, 0.02572918, 0.02777433, 0.02065659, 0.01637697]),
#   'test_r2': array([0.70007109, 0.66570053, 0.6583144 , 0.67260076, 0.66367802]),
#   'test_neg_mean_absolute_error': array([-37129.20908065, -39250.55109541, -39699.92931789, -38508.51980993,
#          -39632.27052963]),
#   'test_neg_root_mean_squared_error': array([-52085.40197984, -55670.30264662, -55790.09145761, -55025.73931183,
#          -56319.0271733 ])},
#  'LinearRegression_Quantile': {'fit_time': array([0.05304098, 0.055233  , 0.06492805, 0.06585741, 0.05097747]),
#   'score_time': array([0.01675749, 0.02785873, 0.02398252, 0.02935195, 0.02677059]),
#   'test_r2': array([0.70685984, 0.674573  , 0.66574077, 0.67834412, 0.67126387]),
#   'test_neg_mean_absolute_error': array([-36795.96736117, -38946.58179308, -39511.03508037, -38278.50485484,
#          -39434.78126978]),
#   'test_neg_root_mean_squared_error': array([-51492.56370018, -54926.57635143, -55180.47512286, -54540.9630218 ,
#          -55680.25746796])}}

# %%
#dataframe comparativo com os resultados de tempo e erros dos modelos para cada 'cross-validation'
df_resultados2 = organiza_resultados(resultados2)

df_resultados2
# Out:
#                         model  fit_time score_time   test_r2  \
# 0              DummyRegressor  0.005951    0.00622  -0.00088
# 1              DummyRegressor  0.007368   0.010182  -0.00007
# 2              DummyRegressor  0.005287   0.007267  -0.00039
# 3              DummyRegressor  0.005199   0.007209 -0.000107
# 4              DummyRegressor  0.005147   0.009276 -0.000134
# 5            LinearRegression  0.039939     0.0208  0.690289
# 6            LinearRegression  0.031878   0.015471  0.666068
# 7            LinearRegression  0.030261   0.015527  0.661041
# 8            LinearRegression  0.030263   0.016774  0.667951
# 9            LinearRegression   0.03298   0.015057  0.663989
# 10     LinearRegression_Power  0.060067   0.016223  0.700071
# 11     LinearRegression_Power  0.105335   0.025729  0.665701
# 12     LinearRegression_Power  0.100529   0.027774  0.658314
# 13     LinearRegression_Power  0.091566   0.020657  0.672601
# 14     LinearRegression_Power  0.064926   0.016377  0.663678
# 15  LinearRegression_Quantile  0.053041   0.016757   0.70686
# 16  LinearRegression_Quantile  0.055233   0.027859  0.674573
# 17  LinearRegression_Quantile  0.064928   0.023983  0.665741
# 18  LinearRegression_Quantile  0.065857   0.029352  0.678344
# 19  LinearRegression_Quantile  0.050977   0.026771  0.671264
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -76256.643008                    -95147.599266     0.012171
# 1                 -76449.683227                    -96287.733882      0.01755
# 2                 -76241.743346                    -95461.554483     0.012553
# 3                 -77052.407298                    -96172.376279     0.012408
# 4                 -77839.121382                    -97119.547925     0.014423
# 5                 -39415.655182                    -52927.949935     0.060739
# 6                 -40876.662885                    -55639.667647     0.047349
# 7                 -41414.432933                    -55567.007594     0.045788
# 8                 -40450.645994                    -55415.078057     0.047037
# 9                 -41326.955146                    -56292.942964     0.048037
# 10                -37129.209081                     -52085.40198      0.07629
# 11                -39250.551095                    -55670.302647     0.131064
# 12                -39699.929318                    -55790.091458     0.128304
# 13                 -38508.51981                    -55025.739312     0.112222
# 14                 -39632.27053                    -56319.027173     0.081303
# 15                -36795.967361                      -51492.5637     0.069798
# 16                -38946.581793                    -54926.576351     0.083092
# 17                 -39511.03508                    -55180.475123     0.088911
# 18                -38278.504855                    -54540.963022     0.095209
# 19                 -39434.78127                    -55680.257468     0.077748

# %%
#comparação das médias das métricas por modelo
df_resultados2.groupby('model').mean()
# Out:
#                            fit_time score_time   test_r2  \
# model
# DummyRegressor              0.00579   0.008031 -0.000316
# LinearRegression           0.033064   0.016726  0.669868
# LinearRegression_Power     0.084485   0.021352  0.672073
# LinearRegression_Quantile  0.058007   0.024944  0.679356
#
#                           test_neg_mean_absolute_error  \
# model
# DummyRegressor                           -76767.919652
# LinearRegression                         -40696.870428
# LinearRegression_Power                   -38844.095967
# LinearRegression_Quantile                -38593.374072
#
#                           test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                               -96037.762367     0.013821
# LinearRegression                             -55168.529239      0.04979
# LinearRegression_Power                       -54978.112514     0.105837
# LinearRegression_Quantile                    -54364.167133     0.082952

# %%
#gráfico comparativos das métricas de cada modelo
plot_comparar_metricas_modelos(df_resultados2)

# %% [markdown]
# Além de **melhorar as métricas de erro**, o modelo com **QuantileTransformer** melhorou o **tempo de treinamento** em relação ao modelo com o Power Transform

# %%
#coeficientes
grid_search.best_estimator_.regressor_['reg'].coef_
# Out:
# array([[-4.49894987e-01, -2.01154214e-01, -5.84299636e-02,
#          3.76521871e-02, -3.00794534e-01, -2.94173090e-01,
#          6.38753151e-03, -7.60412001e-05,  5.42125128e-06,
#         -4.65534347e-05,  7.26635039e-04,  3.77735286e-01,
#          1.81260339e-01, -4.81136161e-01,  2.51307906e+00,
#          8.98603116e-01]])

# %%
#variáveis
grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()
# Out:
# array(['one_hot_encoder__ocean_proximity_INLAND',
#        'one_hot_encoder__ocean_proximity_NEAR BAY',
#        'one_hot_encoder__ocean_proximity_NEAR OCEAN',
#        'ordinal_encoder__median_income_cat', 'remainder__longitude',
#        'remainder__latitude', 'remainder__housing_median_age',
#        'remainder__total_rooms', 'remainder__total_bedrooms',
#        'remainder__population', 'remainder__households',
#        'remainder__median_income', 'remainder__rooms_per_household',
#        'remainder__population_per_household',
#        'remainder__bedrooms_per_room', 'remainder__population_per_room'],
#       dtype=object)

# %%
#criando dataframe dos coeficientes
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()
)

coefs
# Out:
#                                              coeficiente
# remainder__population_per_household            -0.481136
# one_hot_encoder__ocean_proximity_INLAND        -0.449895
# remainder__longitude                           -0.300795
# remainder__latitude                            -0.294173
# one_hot_encoder__ocean_proximity_NEAR BAY      -0.201154
# one_hot_encoder__ocean_proximity_NEAR OCEAN    -0.058430
# remainder__total_rooms                         -0.000076
# remainder__population                          -0.000047
# remainder__total_bedrooms                       0.000005
# remainder__households                           0.000727
# remainder__housing_median_age                   0.006388
# ordinal_encoder__median_income_cat              0.037652
# remainder__rooms_per_household                  0.181260
# remainder__median_income                        0.377735
# remainder__population_per_room                  0.898603
# remainder__bedrooms_per_room                    2.513079

# %%
#analise gráfica do coeficiente do melhor modelo
plot_coeficientes(
    coefs, 
    tituto="Coeficientes")

# %% [markdown]
# Esse modelo valoriza casas com alta proporção de quartos em áreas de alta renda e densidade, e penaliza fortemente casas no interior do estado com muitas pessoas morando debaixo do mesmo teto.
#
# Observe as variáveis no centro do gráfico (housing_median_age, households, total_bedrooms, population, total_rooms). Elas têm coeficientes quase iguais a zero.
# O que isso significa? Isso prova que a  engenharia de recursos (Feature Engineering) foi um sucesso absoluto. O modelo percebeu que saber o número total de quartos em um quarteirão (total_bedrooms) não serve para prever o preço de uma casa. O que importa são as taxas e proporções criadas (como bedrooms_per_room). As variáveis brutas se tornaram redundantes e o modelo inteligentemente as ignorou.

# %%
plot_residuos_estimador(
    grid_search.best_estimator_, 
    X, 
    y,
    fracao_amostra=0.05,
    eng_formatter=True
)

# %% [markdown]
# O grágico de resíduos mostra que o Modelo consegue prever os valor medio das casas com pequeno erro para a maior parte dos valores. E o modelo tem mais erros para uma valor menor que o valor real.
