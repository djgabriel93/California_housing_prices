# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room  population_per_room
# 0           0.146591             0.365909
# 1           0.155797             0.338217
# 2           0.260274             0.472016
# 3           0.252679             0.622321
# 4           0.203216             0.442162

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17515 non-null  float64
#  1   latitude                  17515 non-null  float64
#  2   housing_median_age        17515 non-null  int8
#  3   total_rooms               17515 non-null  int16
#  4   total_bedrooms            17515 non-null  int16
#  5   population                17515 non-null  int16
#  6   households                17515 non-null  int16
#  7   median_income             17515 non-null  float64
#  8   median_house_value        17515 non-null  int32
#  9   ocean_proximity           17515 non-null  category
#  10  median_income_cat         17515 non-null  int64
#  11  rooms_per_household       17515 non-null  float64
#  12  population_per_household  17515 non-null  float64
#  13  bedrooms_per_room         17515 non-null  float64
#  14  population_per_room       17515 non-null  float64
# dtypes: category(1), float64(7), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.3 MB

# %%
#Definir nossas colunas que serão preprocessadas
coluna_target = ['median_house_value']

coluna_one_hot_encoder = ['ocean_proximity']

coluna_ordinal_encoder = ['median_income_cat']

# %%
#Definir X e y
X = df.drop(columns = coluna_target)

y = df[coluna_target]

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room  \
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294118                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343675                  2.362768           0.203216
#
#    population_per_room
# 0             0.365909
# 1             0.338217
# 2             0.472016
# 3             0.622321
# 4             0.442162

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
colunas_robust = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)
colunas_robust
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'population_per_room', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='str')

# %%
colunas_standard = ["longitude","latitude","housing_median_age"]

colunas_power = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder + colunas_standard)
colunas_power
# Out:
# Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_household', 'population_per_room',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='str')

# %%
#criar o preprocessamento

pipeline_robust = Pipeline(steps=[
    ("robust_sacaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers = [
        ("one_hot_encoder", OneHotEncoder(drop='first'),coluna_one_hot_encoder),
        ("ordinal_encoder", OrdinalEncoder(categories='auto'),coluna_ordinal_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust),
    ],
)

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    param_grid=param_grid,
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution='normal'),
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sa...
#        'population_per_room', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='str'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sa...
#        'population_per_room', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='str'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3}

# %%
grid_search.best_score_
# Out:
# np.float64(-51251.83112378458)

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['ocean_proximity']),
#                                                                                       ('ordinal_encoder',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['median_income_cat']),
#                                                                                       ('robust_scaler_poly',
#                                                                                        Pipeline(steps=[('robust_sacaler',
#                                                                                                         RobustScaler()),
#                                                                                                        ('poly',
#                                                                                                         PolynomialFeatures(degree=3,
#                                                                                                                            include_bias=False))]),
#                                                                                        Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'population_per_room', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='str'))])),
#                                                      ('reg',
#                                                       LinearRegression())]),
#                            transformer=QuantileTransformer(output_distribution='normal'))

# %%
grid_search.best_estimator_.regressor_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot_encoder',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['ocean_proximity']),
#                                                  ('ordinal_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['median_income_cat']),
#                                                  ('robust_scaler_poly',
#                                                   Pipeline(steps=[('robust_sacaler',
#                                                                    RobustScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures(degree=3,
#                                                                                       include_bias=False))]),
#                                                   Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'population_per_room', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='str'))])),
#                 ('reg', LinearRegression())])

# %%
# Definindo noss modelos de treino para comparação

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution='normal'),
    },
    
       "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}

# %%
#Treinar e validar modelos

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

resultados
# Out:
# {'DummyRegressor': {'fit_time': array([0.00638962, 0.00558662, 0.00792837, 0.00972128, 0.00893855]),
#   'score_time': array([0.00850058, 0.01535559, 0.01171398, 0.01052761, 0.01178479]),
#   'test_r2': array([-8.79886502e-04, -7.01292589e-05, -3.90446967e-04, -1.07273469e-04,
#          -1.34175423e-04]),
#   'test_neg_mean_absolute_error': array([-76256.6430076 , -76449.68322658, -76241.74334592, -77052.4072976 ,
#          -77839.12138232]),
#   'test_neg_root_mean_squared_error': array([-95147.59926567, -96287.73388159, -95461.5544825 , -96172.37627931,
#          -97119.54792537])},
#  'LinearRegression': {'fit_time': array([0.06279588, 0.05514979, 0.0713625 , 0.0503366 , 0.05837107]),
#   'score_time': array([0.02450013, 0.02802277, 0.02008748, 0.02549839, 0.03117371]),
#   'test_r2': array([0.69028914, 0.66606835, 0.66104148, 0.6679513 , 0.66398948]),
#   'test_neg_mean_absolute_error': array([-39415.65518174, -40876.66288459, -41414.43293308, -40450.64599389,
#          -41326.95514596]),
#   'test_neg_root_mean_squared_error': array([-52927.94993511, -55639.66764696, -55567.0075938 , -55415.07805684,
#          -56292.94296357])},
#  'LinearRegression_target': {'fit_time': array([0.09290624, 0.07207966, 0.06742334, 0.08168292, 0.08385086]),
#   'score_time': array([0.02201915, 0.0251503 , 0.03034616, 0.02309871, 0.02463484]),
#   'test_r2': array([0.70666989, 0.67426966, 0.66614414, 0.67900815, 0.67280286]),
#   'test_neg_mean_absolute_error': array([-36793.53691078, -38939.90978668, -39497.27987736, -38282.97407253,
#          -39380.79134766]),
#   'test_neg_root_mean_squared_error': array([-51509.24367844, -54952.16987341, -55147.17060114, -54484.63608537,
#          -55549.76991851])},
#  'LinearRegression_grid_search': {'fit_time': array([0.60636234, 0.6293776 , 0.66394067, 0.59624791, 0.88560176]),
#   'score_time': array([0.05223536, 0.08143353, 0.04817128, 0.0583775 , 0.07807088]),
#   'test_r2': array([0.73650644, 0.69861713, 0.70141083, 0.71893638, 0.71947004]),
#   'test_neg_mean_absolute_error': array([-33944.20275535, -36366.82981166, -36220.12291038, -35643.29991678,
#          -35700.49480835]),
#   'test_neg_root_mean_squared_error': array([-48819.33445929, -52858.52243366, -52153.17622684, -50983.46768706,
#          -51435.99497522])}}

# %%
#dataframe comparativo com os resultados de tempo e erros dos modelos para cada 'cross-validation'
df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor   0.00639   0.008501  -0.00088
# 1                 DummyRegressor  0.005587   0.015356  -0.00007
# 2                 DummyRegressor  0.007928   0.011714  -0.00039
# 3                 DummyRegressor  0.009721   0.010528 -0.000107
# 4                 DummyRegressor  0.008939   0.011785 -0.000134
# 5               LinearRegression  0.062796     0.0245  0.690289
# 6               LinearRegression   0.05515   0.028023  0.666068
# 7               LinearRegression  0.071362   0.020087  0.661041
# 8               LinearRegression  0.050337   0.025498  0.667951
# 9               LinearRegression  0.058371   0.031174  0.663989
# 10       LinearRegression_target  0.092906   0.022019   0.70667
# 11       LinearRegression_target   0.07208    0.02515   0.67427
# 12       LinearRegression_target  0.067423   0.030346  0.666144
# 13       LinearRegression_target  0.081683   0.023099  0.679008
# 14       LinearRegression_target  0.083851   0.024635  0.672803
# 15  LinearRegression_grid_search  0.606362   0.052235  0.736506
# 16  LinearRegression_grid_search  0.629378   0.081434  0.698617
# 17  LinearRegression_grid_search  0.663941   0.048171  0.701411
# 18  LinearRegression_grid_search  0.596248   0.058378  0.718936
# 19  LinearRegression_grid_search  0.885602   0.078071   0.71947
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -76256.643008                    -95147.599266      0.01489
# 1                 -76449.683227                    -96287.733882     0.020942
# 2                 -76241.743346                    -95461.554483     0.019642
# 3                 -77052.407298                    -96172.376279     0.020249
# 4                 -77839.121382                    -97119.547925     0.020723
# 5                 -39415.655182                    -52927.949935     0.087296
# 6                 -40876.662885                    -55639.667647     0.083173
# 7                 -41414.432933                    -55567.007594      0.09145
# 8                 -40450.645994                    -55415.078057     0.075835
# 9                 -41326.955146                    -56292.942964     0.089545
# 10                -36793.536911                    -51509.243678     0.114925
# 11                -38939.909787                    -54952.169873      0.09723
# 12                -39497.279877                    -55147.170601     0.097769
# 13                -38282.974073                    -54484.636085     0.104782
# 14                -39380.791348                    -55549.769919     0.108486
# 15                -33944.202755                    -48819.334459     0.658598
# 16                -36366.829812                    -52858.522434     0.710811
# 17                 -36220.12291                    -52153.176227     0.712112
# 18                -35643.299917                    -50983.467687     0.654625
# 19                -35700.494808                    -51435.994975     0.963673

# %%
#comparação das médias das métricas por modelo
df_resultados.groupby('model').mean().sort_values(by='test_neg_mean_absolute_error')
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.007713   0.011577 -0.000316
# LinearRegression              0.059603   0.025856  0.669868
# LinearRegression_target       0.079589    0.02505  0.679779
# LinearRegression_grid_search  0.676306   0.063658  0.714988
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76767.919652
# LinearRegression                            -40696.870428
# LinearRegression_target                     -38578.898399
# LinearRegression_grid_search                -35574.990041
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -96037.762367     0.019289
# LinearRegression                                -55168.529239      0.08546
# LinearRegression_target                         -54328.598031     0.104638
# LinearRegression_grid_search                    -51250.099156     0.739964

# %%
#gráfico comparativos das métricas de cada modelo
plot_comparar_metricas_modelos(df_resultados)

# %%
tempo_novo_anterior = df_resultados.groupby('model').mean()['time_seconds']['LinearRegression_grid_search'] / df_resultados.groupby('model').mean()['time_seconds']['LinearRegression_target']
print(f'tempo de processamento do modelo novo foi {tempo_novo_anterior:.0f}x maior que o modelo anterior')
# Out:
# tempo de processamento do modelo novo foi 7x maior que o modelo anterior

# %% [markdown]
# Adicionando um preprocessamento Polinomial de grau 3 em nossas colunas, obtivemos melhores resultado que o modelo anterior, porém o tempo de treinamento desse modelo foi 7x maior que o modelo anterior.

# %%
#coeficientes
grid_search.best_estimator_.regressor_['reg'].coef_[:,:5]
# Out:
# array([[-0.40882522, -0.20942144, -0.05674154, -0.02195089,  0.35313222]])

# %%
#variáveis
#grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()

# %%
#criando dataframe dos coeficientes
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__latitude longitude total_be...    -6.391709
# robust_scaler_poly__households longitude popula...    -5.392858
# robust_scaler_poly__households latitude populat...    -5.196627
# robust_scaler_poly__latitude longitude populati...    -4.864314
# robust_scaler_poly__households^2 latitude             -3.622993
# ...                                                         ...
# robust_scaler_poly__households latitude population     3.072256
# robust_scaler_poly__latitude^2 total_rooms             3.098688
# robust_scaler_poly__longitude population popula...     3.108012
# robust_scaler_poly__households latitude total_b...     4.162187
# robust_scaler_poly__latitude longitude total_rooms     5.230852
#
# [458 rows x 1 columns]

# %%
coefs[coefs['coeficiente'] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs['coeficiente'].between(-3,3)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__households population_per_r...    -2.930737
# robust_scaler_poly__households^2 longitude            -2.732614
# robust_scaler_poly__latitude population populat...    -2.654837
# robust_scaler_poly__latitude^2 total_bedrooms         -2.617867
# robust_scaler_poly__latitude population total_b...    -2.594566
# ...                                                         ...
# robust_scaler_poly__longitude population_per_ho...     2.243811
# robust_scaler_poly__longitude^2 total_rooms            2.503572
# robust_scaler_poly__bedrooms_per_room latitude ...     2.567266
# robust_scaler_poly__bedrooms_per_room latitude ...     2.652385
# robust_scaler_poly__households longitude popula...     2.813349
#
# [442 rows x 1 columns]

# %%
coefs = coefs[~coefs['coeficiente'].between(-3,3)]
coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__latitude longitude total_be...    -6.391709
# robust_scaler_poly__households longitude popula...    -5.392858
# robust_scaler_poly__households latitude populat...    -5.196627
# robust_scaler_poly__latitude longitude populati...    -4.864314
# robust_scaler_poly__households^2 latitude             -3.622993
# robust_scaler_poly__latitude longitude rooms_pe...    -3.465540
# robust_scaler_poly__households latitude median_...    -3.255794
# robust_scaler_poly__longitude^2 total_bedrooms        -3.184761
# robust_scaler_poly__households total_bedrooms t...    -3.101720
# robust_scaler_poly__latitude population populat...     3.005683
# robust_scaler_poly__households longitude total_...     3.054083
# robust_scaler_poly__households latitude population     3.072256
# robust_scaler_poly__latitude^2 total_rooms             3.098688
# robust_scaler_poly__longitude population popula...     3.108012
# robust_scaler_poly__households latitude total_b...     4.162187
# robust_scaler_poly__latitude longitude total_rooms     5.230852

# %%
#analise gráfica dos coeficientes do melhor modelo
plot_coeficientes(
    coefs, 
    tituto="Coeficientes Linear Regression com RobustScaler/Poly/QuantileTransformer")

# %% [markdown]
# A adição do pré-processamento polinomial adicionou uma alta quantidade de coeficientes no modelo, aumentando a complexidade de compreensão do impacto das feaures em nosso target.

# %%
plot_residuos_estimador(
    grid_search.best_estimator_, 
    X, 
    y,
    fracao_amostra=0.1,
    eng_formatter=True
)

# %% [markdown]
# O grágico de resíduos mostra que o Modelo consegue prever os valores medios das casas com pequeno erro para a maior parte dos valores. E o modelo tem mais erros para uma valor menor que o valor real. Visualmente não há grande diferenças no residuos em relação ao modelos anterior, essa comparação pode ser melhor vizualiada na tabela e graficos comparativa de erros feita anteriormente.
